# %%
conda install pytorch torchvision -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DayoBanjo\Anaconda3
#
#   added / updated specs:
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.1                |           py37_0         2.8 MB
#     cudatoolkit-10.0.130       |                0       250.0 MB
#     ninja-1.9.0                |   py37h74a9793_0         238 KB
#     pytorch-1.2.0              |py3.7_cuda100_cudnn7_1       479.3 MB  pytorch
#     torchvision-0.4.0          |       py37_cu100         2.3 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:       734.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        pkgs/main/win-64::cudatoolkit-10.0.130-0
#   ninja              pkgs/main/win-64::ninja-1.9.0-py37h74a9793_0
#   pytorch            pytorch/win-64::pytorch-1.2.0-py3.7_cuda100_cudnn7_1
#   torchvision        pytorch/win-64::torchvision-0.4.0-py37_cu100
#
# The following packages will be UPDATED:
#
#   conda                                       4.7.10-py37_0 --> 4.8.1-py37_0
#
#
#
# Downloading and Extracting Packages
#
# ninja-1.9.0          | 238 KB    |            |   0%
# ninja-1.9.0          | 238 KB    | 6          |   7%
# ninja-1.9.0          | 238 KB    | ##6        |  27%
# ninja-1.9.0          | 238 KB    | ####7      |  47%
# ninja-1.9.0          | 238 KB    | #######4   |  74%
# ninja-1.9.0          | 238 KB    | #########4 |  94%
# ninja-1.9.0          | 238 KB    | ########## | 100%
#
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   0%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  |            |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   1%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 1          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   2%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 2          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   3%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 3          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   4%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 4          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   5%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 5          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   6%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 6          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   7%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 7          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   8%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 8          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |   9%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | 9          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  10%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #          |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  11%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #1         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  12%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #2         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  13%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #3         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  14%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #4         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  15%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #5         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  16%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #6         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  17%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #7         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  18%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #8         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  19%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | #9         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  20%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##         |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  21%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##1        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  22%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##2        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  23%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##3        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  24%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##4        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  25%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##5        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# cudatoolkit-10.0.130 | 250.0 MB  | ##6        |  26%
# ...
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###5       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
# pytorch-1.2.0        | 479.3 MB  | ###6       |  36%
#
# conda-4.8.1          | 2.8 MB    |            |   0%
# conda-4.8.1          | 2.8 MB    |            |   1%
# conda-4.8.1          | 2.8 MB    | 2          |   3%
# conda-4.8.1          | 2.8 MB    | 6          |   6%
# conda-4.8.1          | 2.8 MB    | 8          |   8%
# conda-4.8.1          | 2.8 MB    | 9          |  10%
# conda-4.8.1          | 2.8 MB    | #1         |  12%
# conda-4.8.1          | 2.8 MB    | #4         |  14%
# conda-4.8.1          | 2.8 MB    | #6         |  17%
# conda-4.8.1          | 2.8 MB    | #8         |  18%
# conda-4.8.1          | 2.8 MB    | #9         |  20%
# conda-4.8.1          | 2.8 MB    | ##1        |  21%
# conda-4.8.1          | 2.8 MB    | ##4        |  24%
# conda-4.8.1          | 2.8 MB    | ##5        |  26%
# conda-4.8.1          | 2.8 MB    | ##8        |  28%
# conda-4.8.1          | 2.8 MB    | ##9        |  30%
# conda-4.8.1          | 2.8 MB    | ###1       |  31%
# conda-4.8.1          | 2.8 MB    | ###3       |  33%
# conda-4.8.1          | 2.8 MB    | ###4       |  35%
# conda-4.8.1          | 2.8 MB    | ###6       |  36%
# conda-4.8.1          | 2.8 MB    | ###8       |  39%
# conda-4.8.1          | 2.8 MB    | ####       |  40%
# conda-4.8.1          | 2.8 MB    | ####1      |  42%
# conda-4.8.1          | 2.8 MB    | ####3      |  44%
# conda-4.8.1          | 2.8 MB    | ####5      |  45%
# conda-4.8.1          | 2.8 MB    | ####6      |  47%
# conda-4.8.1          | 2.8 MB    | ####8      |  48%
# conda-4.8.1          | 2.8 MB    | #####      |  50%
# conda-4.8.1          | 2.8 MB    | #####1     |  52%
# conda-4.8.1          | 2.8 MB    | #####3     |  54%
# conda-4.8.1          | 2.8 MB    | #####5     |  56%
# conda-4.8.1          | 2.8 MB    | #####7     |  57%
# conda-4.8.1          | 2.8 MB    | #####8     |  59%
# conda-4.8.1          | 2.8 MB    | ######     |  61%
# conda-4.8.1          | 2.8 MB    | ######2    |  62%
# conda-4.8.1          | 2.8 MB    | ######3    |  64%
# conda-4.8.1          | 2.8 MB    | ######5    |  66%
# conda-4.8.1          | 2.8 MB    | ######7    |  68%
# conda-4.8.1          | 2.8 MB    | ######9    |  69%
# conda-4.8.1          | 2.8 MB    | #######1   |  72%
# conda-4.8.1          | 2.8 MB    | #######3   |  74%
# conda-4.8.1          | 2.8 MB    | #######5   |  75%
# conda-4.8.1          | 2.8 MB    | #######7   |  77%
# conda-4.8.1          | 2.8 MB    | #######8   |  79%
# conda-4.8.1          | 2.8 MB    | ########   |  80%
# conda-4.8.1          | 2.8 MB    | ########2  |  82%
# conda-4.8.1          | 2.8 MB    | ########3  |  84%
# conda-4.8.1          | 2.8 MB    | ########5  |  85%
# conda-4.8.1          | 2.8 MB    | ########7  |  87%
# conda-4.8.1          | 2.8 MB    | ########8  |  89%
# conda-4.8.1          | 2.8 MB    | #########  |  90%
# conda-4.8.1          | 2.8 MB    | #########1 |  92%
# conda-4.8.1          | 2.8 MB    | #########3 |  94%
# conda-4.8.1          | 2.8 MB    | #########5 |  95%
# conda-4.8.1          | 2.8 MB    | #########6 |  97%
# conda-4.8.1          | 2.8 MB    | #########8 |  99%
# conda-4.8.1          | 2.8 MB    | ########## | 100%
#
# Note: you may need to restart the kernel to use updated packages.
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://conda.anaconda.org/pytorch/win-64/pytorch-1.2.0-py3.7_cuda100_cudnn7_1.tar.bz2>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.

# %%
import torch

# %%
def activation(x):
    return 1/(1+torch.exp(-x))

# %%
### Generate some data
torch.manual_seed(7) # Set the random seed so things are predictable

# Features are 5 random normal variables
features = torch.randn((1, 5))
# True weights for our data, random normal variables again
weights = torch.randn_like(features)
# and a true bias term
bias = torch.randn((1, 1))

# %%
y = activation((weights * features).sum() + bias )

# %%
y
# Out:
# tensor([[0.1595]])

# %%
y.shape
# Out:
# torch.Size([1, 1])

# %%
z = y.resize_(2, 1)

# %%
z
# Out:
# tensor([[0.1595],
#         [0.0000]])

# %%
z = z.resize_(1,2)

# %%
z
# Out:
# tensor([[0.1595, 0.0000]])

# %%
#multiply_result = activation(
k= activation(torch.mm(features, weights.view(5,1)) + bias)

# %%
j = activation(torch.mm(features, weights.view(5,1) +bias))

# %%
k = torch.randn((2,3))

# %%
k
# Out:
# tensor([[ 0.2028,  2.4505,  2.0256],
#         [ 1.7792, -0.9179, -0.4578]])

# %%
k.view(3,2)
# Out:
# tensor([[ 0.2028,  2.4505],
#         [ 2.0256,  1.7792],
#         [-0.9179, -0.4578]])

# %%
### Generate some data
torch.manual_seed(7) # Set the random seed so things are predictable

# Features are 3 random normal variables
features = torch.randn((1, 3))

# Define the size of each layer in our network
n_input = features.shape[1]     # Number of input units, must match number of input features
n_hidden = 2                    # Number of hidden units 
n_output = 1                    # Number of output units

# Weights for inputs to hidden layer
W1 = torch.randn(n_input, n_hidden)
# Weights for hidden layer to output layer
W2 = torch.randn(n_hidden, n_output)

# and bias terms for hidden and output layers
B1 = torch.randn((1, n_hidden))
B2 = torch.randn((1, n_output))

# %%
features.shape,W1.shape
# Out:
# (torch.Size([1, 3]), torch.Size([3, 2]))

# %%
features, W1
# Out:
# (tensor([[-0.1468,  0.7861,  0.9468]]), tensor([[-1.1143,  1.6908],
#          [-0.8948, -0.3556],
#          [ 1.2324,  0.1382]]))

# %%
h= activation(torch.mm(features,W1) + B1)
output = activation(torch.mm(h, W2) + B2)

# %%
output
# Out:
# tensor([[0.3171]])

# %%
import numpy as np

# %%
a = np.random.rand(4,3)
b = torch.from_numpy(a)

# %%
a,b
# Out:
# (array([[0.67950231, 0.30632292, 0.09739535],
#         [0.22201281, 0.8734003 , 0.16911713],
#         [0.98181159, 0.68644502, 0.30451184],
#         [0.72831073, 0.81351399, 0.24998659]]),
#  tensor([[0.6795, 0.3063, 0.0974],
#          [0.2220, 0.8734, 0.1691],
#          [0.9818, 0.6864, 0.3045],
#          [0.7283, 0.8135, 0.2500]], dtype=torch.float64))

# %%
b.numpy()
# Out:
# array([[0.67950231, 0.30632292, 0.09739535],
#        [0.22201281, 0.8734003 , 0.16911713],
#        [0.98181159, 0.68644502, 0.30451184],
#        [0.72831073, 0.81351399, 0.24998659]])

# %%
b.mul_(3)
# Out:
# tensor([[2.0385, 0.9190, 0.2922],
#         [0.6660, 2.6202, 0.5074],
#         [2.9454, 2.0593, 0.9135],
#         [2.1849, 2.4405, 0.7500]], dtype=torch.float64)

# %%
a
# Out:
# array([[2.03850693, 0.91896877, 0.29218605],
#        [0.66603844, 2.6202009 , 0.50735138],
#        [2.94543476, 2.05933507, 0.91353551],
#        [2.1849322 , 2.44054197, 0.74995976]])
